# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plot_helper as ph
import matplotlib as mpl

ph.font_format()

# %%
fig, ax = plt.subplots()
ph.generate_cbar(cmap=ph.red)

# %%
x = np.arange(10)
y = 10 * x + np.random.normal(10)

fig, ax = plt.subplots()
sca = ax.scatter(x,y)
lines = ax.plot(x,y)

ax.set_xticks([0,1,2,5,10])
ax.set_yticks([0,10,20,50,100])

ph.scatter_format(sca)
ph.line_format(lines)
ph.format((100,100))

ph.label_format()
fig.savefig('sca.svg', **ph.svg)
plt.show()

# %%
df = pd.DataFrame(np.arange(120).reshape(5,-1)).T
data = df.to_numpy()

fig, ax = plt.subplots()
_ = ph.boxplot(data, whis=1.5)
ax.set_xticks([0,1,2,3,4,5])
ax.set_yticks([0,10,20,50,100])

ph.format((100,100))
ph.label_format()

fig.savefig('box.svg', **ph.svg)

# %%
x = np.arange(10)
y = 1 * x + 0.25 * np.random.normal(10)
fig, ax = plt.subplots()
lines = ax.plot(x,y)
ax.set_xticks([0,1,2,5,10])
ax.set_yticks([0,1,2,5,10])
ax.set_xlabel(r'$x$ label in TeX: $x_\mathrm{subscript}$')
ax.set_ylabel(r'$y$ label in TeX: $y^\mathrm{superscript}$')

ph.line_format(lines)
ph.format((100,100))
ph.label_format()
fig.savefig('line.svg', **ph.svg)

# %%
x = np.arange(10)
y = 1 * x + 0.25 * np.random.normal(10)
fig, ax = plt.subplots()
lines = ax.plot(x,y)
ax.set_xticks([0,1,2,5,10])
ax.set_yticks([0,1,2,5,10])
ax.set_xlabel('')
ax.set_ylabel('')

ph.line_format(lines)
ph.format((100,100))
ph.label_format(show_ticks=False,
           show_labels=False)
fig.savefig('line_no_label.svg', **ph.svg)
